# %%
import pandas as pd
import numpy as np
from sklearn.utils import shuffle
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('features_30_sec.csv')
df.head(5)
# Out:
#           filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1  blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2  blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3  blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4  blues.00004.wav  661794          0.308526         0.087841  0.091529
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.002827             1784.165850          129774.064525
# 1  0.002373             1530.176679          375850.073649
# 2  0.002746             1552.811865          156467.643368
# 3  0.006346             1070.106615          184355.942417
# 4  0.002303             1835.004266          343399.939274
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              2002.449060            85882.761315  ...   52.420910
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 60 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   filename                 1000 non-null   object
#  1   length                   1000 non-null   int64
#  2   chroma_stft_mean         1000 non-null   float64
#  3   chroma_stft_var          1000 non-null   float64
#  4   rms_mean                 1000 non-null   float64
#  5   rms_var                  1000 non-null   float64
#  6   spectral_centroid_mean   1000 non-null   float64
#  7   spectral_centroid_var    1000 non-null   float64
#  8   spectral_bandwidth_mean  1000 non-null   float64
#  9   spectral_bandwidth_var   1000 non-null   float64
#  10  rolloff_mean             1000 non-null   float64
#  11  rolloff_var              1000 non-null   float64
#  12  zero_crossing_rate_mean  1000 non-null   float64
# ...

# %%
def missing_values_table(df):
        miss = df.isnull().sum()
        percent = miss/len(df)*100
        miss_df = pd.concat([miss, percent], axis=1)
        miss_df = miss_df.rename(columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        return miss_df

# %%
missing_values_table(df)
# Out:
#                          Missing Values  % of Total Values
# filename                              0                0.0
# length                                0                0.0
# chroma_stft_mean                      0                0.0
# chroma_stft_var                       0                0.0
# rms_mean                              0                0.0
# rms_var                               0                0.0
# spectral_centroid_mean                0                0.0
# spectral_centroid_var                 0                0.0
# spectral_bandwidth_mean               0                0.0
# spectral_bandwidth_var                0                0.0
# rolloff_mean                          0                0.0
# rolloff_var                           0                0.0
# zero_crossing_rate_mean               0                0.0
# zero_crossing_rate_var                0                0.0
# harmony_mean                          0                0.0
# ...

# %%
df =  df.drop(['filename'], 1)
df
# Out:
#      length  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0    661794          0.350088         0.088757  0.130228  0.002827
# 1    661794          0.340914         0.094980  0.095948  0.002373
# 2    661794          0.363637         0.085275  0.175570  0.002746
# 3    661794          0.404785         0.093999  0.141093  0.006346
# 4    661794          0.308526         0.087841  0.091529  0.002303
# ..      ...               ...              ...       ...       ...
# 995  661794          0.352063         0.080487  0.079486  0.000345
# 996  661794          0.398687         0.075086  0.076458  0.000588
# 997  661794          0.432142         0.075268  0.081651  0.000322
# 998  661794          0.362485         0.091506  0.083860  0.001211
# 999  661794          0.358401         0.085884  0.054454  0.000336
#
#      spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0               1784.165850          129774.064525              2002.449060
# ...

# %%
df.describe()
# Out:
#               length  chroma_stft_mean  chroma_stft_var     rms_mean  \
# count    1000.000000       1000.000000      1000.000000  1000.000000
# mean   662030.846000          0.378682         0.086340     0.130930
# std      1784.073992          0.081705         0.007735     0.065683
# min    660000.000000          0.171939         0.044555     0.005276
# 25%    661504.000000          0.319562         0.082298     0.086657
# 50%    661794.000000          0.383148         0.086615     0.122443
# 75%    661794.000000          0.435942         0.091256     0.175682
# max    675808.000000          0.663685         0.108111     0.397973
#
#            rms_var  spectral_centroid_mean  spectral_centroid_var  \
# count  1000.000000             1000.000000           1.000000e+03
# mean      0.003051             2201.780898           4.696916e+05
# std       0.003634              715.960600           4.008995e+05
# min       0.000004              570.040355           7.911251e+03
# ...

# %%
#for  feature in (df.drop(['label'], 1).columns):
#    df.hist(feature)

# %%
def drop_outliners(df, df_q, features):
    outliners = []
    for feature in features:
        out_l = df[(df[feature]>df_q.iloc[1][feature]) | (df[feature]<df_q.iloc[0][feature])]
        outliners_count = len(out_l.index)
        if outliners_count < 3 and outliners_count > 0 :
            outliners.append(feature)
            #print (out_l)
            df = df.drop(out_l.index)
    print('Outliners in: ', outliners)
    return df

# %%
df_q =  df.quantile([0.001, 0.999])
features = df.drop(['label'], 1).columns
#print(features)
df = drop_outliners(df, df_q, features)
# Out:
# Outliners in:  ['length', 'chroma_stft_mean', 'chroma_stft_var', 'rms_mean', 'rms_var', 'spectral_centroid_mean', 'spectral_centroid_var', 'spectral_bandwidth_mean', 'spectral_bandwidth_var', 'rolloff_mean', 'zero_crossing_rate_mean', 'harmony_mean', 'perceptr_mean', 'perceptr_var', 'tempo', 'mfcc1_mean', 'mfcc1_var', 'mfcc2_mean', 'mfcc2_var', 'mfcc3_mean', 'mfcc3_var', 'mfcc4_mean', 'mfcc4_var', 'mfcc5_mean', 'mfcc5_var', 'mfcc6_mean', 'mfcc6_var', 'mfcc7_mean', 'mfcc7_var', 'mfcc8_mean', 'mfcc8_var', 'mfcc9_mean', 'mfcc9_var', 'mfcc10_mean', 'mfcc10_var', 'mfcc11_mean', 'mfcc11_var', 'mfcc12_mean', 'mfcc12_var', 'mfcc14_mean', 'mfcc15_mean', 'mfcc15_var', 'mfcc16_mean', 'mfcc17_mean', 'mfcc17_var', 'mfcc18_var', 'mfcc19_mean', 'mfcc20_mean', 'mfcc20_var']

# %%
df
# Out:
#      length  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0    661794          0.350088         0.088757  0.130228  0.002827
# 1    661794          0.340914         0.094980  0.095948  0.002373
# 2    661794          0.363637         0.085275  0.175570  0.002746
# 3    661794          0.404785         0.093999  0.141093  0.006346
# 4    661794          0.308526         0.087841  0.091529  0.002303
# ..      ...               ...              ...       ...       ...
# 995  661794          0.352063         0.080487  0.079486  0.000345
# 996  661794          0.398687         0.075086  0.076458  0.000588
# 997  661794          0.432142         0.075268  0.081651  0.000322
# 998  661794          0.362485         0.091506  0.083860  0.001211
# 999  661794          0.358401         0.085884  0.054454  0.000336
#
#      spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0               1784.165850          129774.064525              2002.449060
# ...

# %%
#f, ax = plt.subplots(figsize=(15, 15))
#sns.heatmap(df.corr(), annot=True)

# %%
mms=StandardScaler()
features = df.drop(['label'], 1).columns
df[features] = mms.fit_transform(df[features])

# %%
df = df.drop(['label'], 1)

# %%
pca = PCA()
pca.n_components=2
x_pca = pca.fit_transform(df)

# %%
kmeans=KMeans(n_clusters=3, init="k-means++")
cl=kmeans.fit_predict(x_pca)

# %%
x_pca
#y_train = [0, 1, 2, 0, 3,...  ,4, 5, 6, ,7, 0 , 8, 9]
# Out:
# array([[-2.8902382 ,  1.04007324],
#        [ 1.89462157,  1.2497192 ],
#        [-2.94592619,  1.59458828],
#        ...,
#        [-6.24752804,  1.29480975],
#        [-0.81021517,  2.02531599],
#        [-1.23001896,  2.2981201 ]])

# %%
def get_plot(x_pca, cl, n):
    plt.figure(figsize=(14, 14))
    for i in range(n):
        plt.scatter(x_pca[cl==i, 0], x_pca[cl==i, 1], label=i)
    plt.legend()

# %%
get_plot(x_pca, cl, 3)

# %%
kmeans=KMeans(n_clusters=10, init="k-means++")
cl=kmeans.fit_predict(x_pca)

# %%
get_plot(x_pca, cl, 10)

# %%
import plotly.express as px
pca = PCA()
pca.n_components=3
x_pca = pca.fit_transform(df)
kmeans=KMeans(n_clusters=3, init="k-means++")
cl=kmeans.fit_predict(x_pca)

# %%
def get_df_plot(x_pca, n):
    df_plot=pd.DataFrame(x_pca)
    labels=kmeans.labels_
    df_plot['Cl']=pd.Series(labels)
    cluster_names={i: f'Claster {i}' for i in range(n)}
    df_plot['Cl']=df_plot['Cl'].map(cluster_names)
    return df_plot

# %%
df_plot = get_df_plot(x_pca, 3)

# %%
scatter=px.scatter_3d(x=0,y=1,z=2,data_frame=df_plot,color=df_plot['Cl'])
scatter.show()
# Out:
# <div>                            <div id="629e182c-b05e-4f84-b5d7-491e38818de7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("629e182c-b05e-4f84-b5d7-491e38818de7")) {                    Plotly.newPlot(                        "629e182c-b05e-4f84-b5d7-491e38818de7",                        [{"hovertemplate": "Cl=Claster 1<br>0=%{x}<br>1=%{y}<br>2=%{z}<extra></extra>", "legendgroup": "Claster 1", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Claster 1", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-2.8902382032645666, -2.945926187641806, -3.5193195159448925, -5.928088059430304, -4.770599502521573, -4.9678431794155475, -4.136725004275394, -3.970489792824557, -5.014663246894864, -4.323748695343586, 
# ...

# %%
pca = PCA()
pca.n_components=3
x_pca = pca.fit_transform(df)
kmeans=KMeans(n_clusters=10, init="k-means++")
cl=kmeans.fit_predict(x_pca)

# %%
df_plot = get_df_plot(x_pca, 10)

# %%
scatter=px.scatter_3d(x=0,y=1,z=2,data_frame=df_plot,color=df_plot['Cl'])
scatter.show()
# Out:
# <div>                            <div id="6cc63cfe-5953-4566-a784-eb79c44733d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6cc63cfe-5953-4566-a784-eb79c44733d2")) {                    Plotly.newPlot(                        "6cc63cfe-5953-4566-a784-eb79c44733d2",                        [{"hovertemplate": "Cl=Claster 2<br>0=%{x}<br>1=%{y}<br>2=%{z}<extra></extra>", "legendgroup": "Claster 2", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Claster 2", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-2.8902382033861715, -2.9459261881739813, 0.7590434237125663, 0.9564077130029234, -0.6308301326005006, -0.728790047459618, -0.0328709837026271, -1.997914525653485, 0.9051254490777789, 1.2246613941231332,
# ...

# %%
dis = []
for k in range(1,20):
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(df)
    dis.append(kmeanModel.inertia_)
plt.figure(figsize=(14,14))
plt.plot(range(1,20), dis, 'bx-')
plt.xlabel('Number of clusters')
plt.show()
